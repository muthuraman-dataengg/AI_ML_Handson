# %%
print("all ok")
# Out:
# all ok

# %%
! pip install langchain-community
# !pip install pypdf
# !pip install python-docx
# !pip install pandas
# !pip install openpyxl
# !pip install beautifulsoup4
# !pip install docx2txt
# !pip install jq
# !pip install unstructured

# %%
from langchain_community.document_loaders import (
    TextLoader,
    PyPDFLoader,
    CSVLoader,
    Docx2txtLoader,
    UnstructuredHTMLLoader,
    JSONLoader,
)
# Out:
# /tmp/ipykernel_2549/1332815025.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import (

# %%
loader = PyPDFLoader("/content/sample_document.pdf")
loader
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-04T16:55:50+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-04T16:55:50+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': '/content/sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='LangChain PDF Loader Sample\nThis PDF is used to demonstrate PyPDFLoader in LangChain.\nRefund Policy\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\nSupport SLA\nPriority 1 tickets should receive a first response within 2 hours.\nPolicy\nOwner\nUpdate Frequency\nRefund Policy\nSupport\nQuarterly\nLeave Policy\nHR\nYearly')]

# %%
docs[0].metadata
# Out:
# {'producer': 'ReportLab PDF Library - (opensource)',
#  'creator': '(unspecified)',
#  'creationdate': '2026-07-04T16:55:50+00:00',
#  'author': '(anonymous)',
#  'keywords': '',
#  'moddate': '2026-07-04T16:55:50+00:00',
#  'subject': '(unspecified)',
#  'title': '(anonymous)',
#  'trapped': '/False',
#  'source': '/content/sample_document.pdf',
#  'total_pages': 1,
#  'page': 0,
#  'page_label': '1'}

# %%
docs[0].page_content
# Out:
# 'LangChain PDF Loader Sample\nThis PDF is used to demonstrate PyPDFLoader in LangChain.\nRefund Policy\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\nSupport SLA\nPriority 1 tickets should receive a first response within 2 hours.\nPolicy\nOwner\nUpdate Frequency\nRefund Policy\nSupport\nQuarterly\nLeave Policy\nHR\nYearly'

# %%
txt_loader = TextLoader("/content/sample_text.txt")
txt_loader
txt_docs = txt_loader.load()
txt_docs
# Out:
# [Document(metadata={'source': '/content/sample_text.txt'}, page_content='LangChain Starter Parser Sample\n\nThis text file is used to demonstrate TextLoader.\n\nRAG stands for Retrieval-Augmented Generation. In a RAG pipeline, documents are parsed, split into chunks, converted into embeddings, stored in a vector database, and retrieved at query time.\n\nRefund Policy Example:\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n')]

# %%
txt_docs[0].metadata
# Out:
# {'source': '/content/sample_text.txt'}

# %%
txt_docs[0].page_content
# Out:
# 'LangChain Starter Parser Sample\n\nThis text file is used to demonstrate TextLoader.\n\nRAG stands for Retrieval-Augmented Generation. In a RAG pipeline, documents are parsed, split into chunks, converted into embeddings, stored in a vector database, and retrieved at query time.\n\nRefund Policy Example:\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n'

# %%
csv_loader = CSVLoader("/content/sample_data.csv")
csv_loader
csv_docs = csv_loader.load()
csv_docs
# Out:
# [Document(metadata={'source': '/content/sample_data.csv', 'row': 0}, page_content='policy_id: P-001\ndepartment: HR\ntopic: Leave Policy\ndetails: Employees get 18 paid leaves per year.\nlast_updated: 2026-01-10'),
#  Document(metadata={'source': '/content/sample_data.csv', 'row': 1}, page_content='policy_id: P-002\ndepartment: Finance\ntopic: Reimbursement\ndetails: Travel reimbursement must be submitted within 15 days.\nlast_updated: 2026-02-05'),
#  Document(metadata={'source': '/content/sample_data.csv', 'row': 2}, page_content='policy_id: P-003\ndepartment: Support\ntopic: Refund Policy\ndetails: Refunds are allowed within 7 days of purchase.\nlast_updated: 2026-03-12')]

# %% [markdown]
# jq_schema=".[]" means treat the root of the JSON as an array and process each element individually.
# If sample_data.json contains 100 objects in the top-level array, JSONLoader will create 100 Document objects—one for each object.
#
# text_content=False tells the loader that the extracted values are structured JSON objects rather than plain text, so it will preserve and serialize that structured content into the resulting Document objects.

# %% [markdown]
# | `jq_schema` returns                                                  | `text_content` |
# | -------------------------------------------------------------------- | -------------- |
# | `"Hello World"` (string)                                             | `True`         |
# | `"Machine Learning"` (string)                                        | `True`         |
# | `{"name":"John"}` (JSON object)                                      | `False`        |
# | `{"question":"AI","answer":"Artificial Intelligence"}` (JSON object) | `False`        |
# | `[1,2,3]` (JSON array)                                               | `False`        |

# %%
json_loader = JSONLoader("/content/sample_data.json",jq_schema=".[]",text_content=False)
json_loader
docs =json_loader.load()
docs
# Out:
# [Document(metadata={'source': '/content/sample_data.json', 'seq_num': 1}, page_content='{"id": "doc-001", "title": "Refund Policy", "content": "Refunds are allowed within 7 days of purchase if the product is unused.", "metadata": {"department": "Support", "source": "policy_portal"}}'),
#  Document(metadata={'source': '/content/sample_data.json', 'seq_num': 2}, page_content='{"id": "doc-002", "title": "Leave Policy", "content": "Employees receive 18 paid leaves per year and 8 sick leaves per year.", "metadata": {"department": "HR", "source": "employee_handbook"}}'),
#  Document(metadata={'source': '/content/sample_data.json', 'seq_num': 3}, page_content='{"id": "doc-003", "title": "Security Policy", "content": "API keys must be stored in a secure secrets manager and never committed to Git.", "metadata": {"department": "Engineering", "source": "security_manual"}}')]

# %%
#text_content=True
json_loader_test = JSONLoader("/content/sample_data.json",jq_schema=".[].content",text_content=True)
json_loader_test
docs =json_loader_test.load()
docs
# Out:
# [Document(metadata={'source': '/content/sample_data.json', 'seq_num': 1}, page_content='Refunds are allowed within 7 days of purchase if the product is unused.'),
#  Document(metadata={'source': '/content/sample_data.json', 'seq_num': 2}, page_content='Employees receive 18 paid leaves per year and 8 sick leaves per year.'),
#  Document(metadata={'source': '/content/sample_data.json', 'seq_num': 3}, page_content='API keys must be stored in a secure secrets manager and never committed to Git.')]

# %%
#Loads nested JSON
json_loader_test = JSONLoader("/content/sample_data.json",jq_schema=".[].metadata",text_content=False)
json_loader_test
docs =json_loader_test.load()
docs
# Out:
# [Document(metadata={'source': '/content/sample_data.json', 'seq_num': 1}, page_content='{"department": "Support", "source": "policy_portal"}'),
#  Document(metadata={'source': '/content/sample_data.json', 'seq_num': 2}, page_content='{"department": "HR", "source": "employee_handbook"}'),
#  Document(metadata={'source': '/content/sample_data.json', 'seq_num': 3}, page_content='{"department": "Engineering", "source": "security_manual"}')]

# %%
docx_loader = Docx2txtLoader("/content/sample_document.docx")
docx_loader
docx = docx_loader.load()
docx
# Out:
# [Document(metadata={'source': '/content/sample_document.docx'}, page_content='LangChain DOCX Loader Sample\n\nThis document is used to demonstrate Docx2txtLoader in LangChain.\n\nRefund Policy\n\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n\nLeave Policy\n\nEmployees receive 18 paid leaves per year and 8 sick leaves per year.\n\nSimple Table\n\nPolicy\n\nOwner\n\nUpdate Frequency\n\nRefund Policy\n\nSupport\n\nQuarterly\n\nLeave Policy\n\nHR\n\nYearly')]

# %%
html_parser = UnstructuredHTMLLoader("/content/sample_page.html")
html = html_parser.load()
html
# Out:
# [Document(metadata={'source': '/content/sample_page.html'}, page_content='Company Knowledge Base\n\nRefund Policy\n\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n\nSupport SLA\n\nPriority 1 tickets should receive a first response within 2 hours.\n\nChannel: Email\n\nChannel: Chat\n\nChannel: Phone')]

# %%
# ============================================================
# 1. File Path
# ============================================================
import os
from pathlib import Path

PDF_PATH = "/content/complex_rag_parsing_sample_with_sunny_image.pdf"

OUTPUT_DIR = Path("/content/parsed_complex_pdf_output")

IMAGE_DIR = OUTPUT_DIR / "extracted_images"
PAGE_IMAGE_DIR = OUTPUT_DIR / "page_images"

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
IMAGE_DIR.mkdir(parents=True, exist_ok=True)
PAGE_IMAGE_DIR.mkdir(parents=True, exist_ok=True)

print("PDF exists:", os.path.exists(PDF_PATH))
# Out:
# PDF exists: True

# %%
# ============================================================
# 2. Helper: Safe OCR
# ============================================================

def run_ocr_on_image(image_path):
    """
    Runs OCR on image using pytesseract.
    If tesseract is not installed in system, it will return empty text.
    """
    try:
        import pytesseract
        img = Image.open(image_path)
        text = pytesseract.image_to_string(img)
        return text.strip()
    except Exception as e:
        return f"[OCR_SKIPPED_OR_FAILED: {str(e)}]"

# %%
run_ocr_on_image("D:\complete_content_new\Full-Stack-GenAI-Bootcamp-1.0\Class-30-Data-Parsing-for-RAG\data\parsed_complex_pdf_output\extracted_images\page_002_image_1.png")

# %%
# !pip install PyMuPDF
# !pip install fitz
# !pip install pytesseract
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 770.1 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 42.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
# ...

# %%
# Install dependencies

import os
import json
import fitz  # PyMuPDF
import pdfplumber
import pandas as pd
from PIL import Image
from pathlib import Path
from langchain_core.documents import Document

# %%
# ============================================================
# 3. Extract Text + Images using PyMuPDF
# ============================================================

def extract_text_and_images(pdf_path):
    doc = fitz.open(pdf_path)

    page_records = []
    image_records = []

    for page_index in range(len(doc)):
        page = doc[page_index]
        page_number = page_index + 1

        # Extract normal selectable text
        text = page.get_text("text")

        # Extract page metadata-like info
        page_info = {
            "page_number": page_number,
            "text": text.strip(),
            "image_count": len(page.get_images(full=True)),
            "width": page.rect.width,
            "height": page.rect.height,
        }

        page_records.append(page_info)

        # Render full page as image for OCR
        pix = page.get_pixmap(matrix=fitz.Matrix(2, 2))
        page_image_path = PAGE_IMAGE_DIR / f"page_{page_number:03d}.png"
        pix.save(str(page_image_path))

        # OCR full page image
        ocr_text = run_ocr_on_image(page_image_path)
        page_info["ocr_text"] = ocr_text
        page_info["page_image_path"] = str(page_image_path)

        # Extract embedded images
        images = page.get_images(full=True)

        for img_index, img in enumerate(images):
            xref = img[0]
            base_image = doc.extract_image(xref)

            image_bytes = base_image["image"]
            image_ext = base_image["ext"]

            image_path = IMAGE_DIR / f"page_{page_number:03d}_image_{img_index + 1}.{image_ext}"

            with open(image_path, "wb") as f:
                f.write(image_bytes)

            image_ocr_text = run_ocr_on_image(image_path)

            image_records.append({
                "page_number": page_number,
                "image_index": img_index + 1,
                "image_path": str(image_path),
                "image_ext": image_ext,
                "image_ocr_text": image_ocr_text
            })

    doc.close()

    return page_records, image_records


page_records, image_records = extract_text_and_images(PDF_PATH)

print("Total pages parsed:", len(page_records))
print("Total images extracted:", len(image_records))
# Out:
# Total pages parsed: 24
# Total images extracted: 13

# %%
page_records
# Out:
# [{'page_number': 1,
# ...

# %%
image_records
# Out:
# [{'page_number': 2,
#   'image_index': 1,
#   'image_path': '/content/parsed_complex_pdf_output/extracted_images/page_002_image_1.png',
#   'image_ext': 'png',
#   'image_ocr_text': 'Contract Processing Ownership Map\n\n    \n    \n\nClient Admin Audit Team\n\n  \n\nVector DB Document Store'},
#  {'page_number': 7,
#   'image_index': 1,
#   'image_path': '/content/parsed_complex_pdf_output/extracted_images/page_007_image_1.png',
#   'image_ext': 'png',
#   'image_ocr_text': 'RAG Ingestion and Retrieval Flow\n\nRaw Files Parser Chunks Vector DB\nPDF / DOCX / HTML Text + Tables Sections + Metada| Embeddings\n\nUser Query Retriever LLM\n\nquestion top-k chunks grounded answer\n\n \n\nParsing challenge: each stage can improve or damage answer quality.'},
#  {'page_number': 9,
#   'image_index': 1,
#   'image_path': '/content/parsed_complex_pdf_output/extracted_images/page_009_image_1.png',
#   'image_ext': 'png',
# ...

# %%
# ============================================================
# 4. Extract Tables using pdfplumber
# ============================================================

def extract_tables(pdf_path):
    table_records = []

    with pdfplumber.open(pdf_path) as pdf:
        for page_index, page in enumerate(pdf.pages):
            page_number = page_index + 1

            try:
                tables = page.extract_tables()
            except Exception as e:
                tables = []
                print(f"Table extraction failed on page {page_number}: {e}")

            for table_index, table in enumerate(tables):
                if not table:
                    continue

                # Clean table rows
                cleaned_table = []
                for row in table:
                    cleaned_row = [
                        cell.strip() if isinstance(cell, str) else cell
                        for cell in row
                    ]
                    cleaned_table.append(cleaned_row)

                # Convert to DataFrame safely
                try:
                    df = pd.DataFrame(cleaned_table[1:], columns=cleaned_table[0])
                except Exception:
                    df = pd.DataFrame(cleaned_table)

                table_records.append({
                    "page_number": page_number,
                    "table_index": table_index + 1,
                    "raw_table": cleaned_table,
                    "markdown": df.to_markdown(index=False),
                    "csv": df.to_csv(index=False)
                })

    return table_records


table_records = extract_tables(PDF_PATH)

print("Total tables extracted:", len(table_records))

for table in table_records[:3]:
    print("\nPage:", table["page_number"], "Table:", table["table_index"])
    print(table["markdown"][:1000])
# Out:
# Total tables extracted: 16
#
# Page: 1 Table: 1
# | Section               | Parsing challenge                       | Why it matters for RAG                  |
# |:----------------------|:----------------------------------------|:----------------------------------------|
# | Contracts             | Dense legal text, clause numbers, cross | Need section-aware chunks and citations |
# |                       | references                              |                                         |
# | Tables                | Merged headers, numeric columns,        | Need row/column preservation            |
# |                       | footnotes                               |                                         |
# | Images                | Architecture diagram, heatmap, scanned  | Need OCR or multimodal extraction       |
# |                       | form                                    |                                         |
# ...

# %%
# ============================================================
# 5. Create LangChain Documents
# ============================================================

langchain_docs = []

# 5.1 Page text documents
for page in page_records:
    page_number = page["page_number"]

    combined_text = f"""
PAGE {page_number}

SELECTABLE TEXT:
{page["text"]}

OCR TEXT:
{page["ocr_text"]}
""".strip()

    doc = Document(
        page_content=combined_text,
        metadata={
            "source": PDF_PATH,
            "page_number": page_number,
            "content_type": "page_text_plus_ocr",
            "image_count": page["image_count"],
            "page_image_path": page["page_image_path"],
        }
    )

    langchain_docs.append(doc)


# 5.2 Table documents
for table in table_records:
    page_number = table["page_number"]

    table_text = f"""
TABLE FOUND ON PAGE {page_number}
TABLE INDEX: {table["table_index"]}

TABLE MARKDOWN:
{table["markdown"]}
""".strip()

    doc = Document(
        page_content=table_text,
        metadata={
            "source": PDF_PATH,
            "page_number": page_number,
            "content_type": "table",
            "table_index": table["table_index"],
        }
    )

    langchain_docs.append(doc)

# %%
# 5.3 Image OCR documents
for image in image_records:
    page_number = image["page_number"]

    image_text = f"""
IMAGE FOUND ON PAGE {page_number}
IMAGE INDEX: {image["image_index"]}
IMAGE PATH: {image["image_path"]}

IMAGE OCR TEXT:
{image["image_ocr_text"]}
""".strip()

    doc = Document(
        page_content=image_text,
        metadata={
            "source": PDF_PATH,
            "page_number": page_number,
            "content_type": "image",
            "image_index": image["image_index"],
            "image_path": image["image_path"],
            "image_ext": image["image_ext"],
        }
    )

    langchain_docs.append(doc)


print("Total LangChain Documents created:", len(langchain_docs))
# Out:
# Total LangChain Documents created: 53

# %%
# ============================================================
# 6. Save Parsed Output
# ============================================================

# Save page records
with open(OUTPUT_DIR / "page_records.json", "w", encoding="utf-8") as f:
    json.dump(page_records, f, indent=2, ensure_ascii=False)

# Save image records
with open(OUTPUT_DIR / "image_records.json", "w", encoding="utf-8") as f:
    json.dump(image_records, f, indent=2, ensure_ascii=False)

# Save table records
with open(OUTPUT_DIR / "table_records.json", "w", encoding="utf-8") as f:
    json.dump(table_records, f, indent=2, ensure_ascii=False)

# Save all LangChain document content as markdown
with open(OUTPUT_DIR / "rag_ready_documents.md", "w", encoding="utf-8") as f:
    for i, doc in enumerate(langchain_docs):
        f.write(f"\n\n# Document {i + 1}\n")
        f.write(f"\nMetadata:\n```json\n{json.dumps(doc.metadata, indent=2)}\n```\n")
        f.write("\nContent:\n")
        f.write(doc.page_content)
        f.write("\n\n---\n")

# Save table markdown separately
with open(OUTPUT_DIR / "extracted_tables.md", "w", encoding="utf-8") as f:
    for table in table_records:
        f.write(f"\n\n## Page {table['page_number']} - Table {table['table_index']}\n\n")
        f.write(table["markdown"])
        f.write("\n\n---\n")

print("\nSaved outputs in:", OUTPUT_DIR)
# Out:
# Saved outputs in: /content/parsed_complex_pdf_output

# %%
# ============================================================
# 7. Preview Parsed Output
# ============================================================

print("\n================ PAGE TEXT PREVIEW ================\n")
print(langchain_docs[0].page_content[:1500])

print("\n================ TABLE PREVIEW ================\n")
table_docs = [doc for doc in langchain_docs if doc.metadata["content_type"] == "table"]

if table_docs:
    print(table_docs[0].page_content[:1500])
else:
    print("No table docs found.")

print("\n================ IMAGE OCR PREVIEW ================\n")
image_docs = [doc for doc in langchain_docs if doc.metadata["content_type"] == "image"]

if image_docs:
    print(image_docs[0].page_content[:1500])
else:
    print("No image docs found.")
# Out:
# ================ PAGE TEXT PREVIEW ================
#
# PAGE 1
#
# SELECTABLE TEXT:
# Complex RAG Parsing Sample - synthetic document
# Page 1
# Complex Document for RAG Parsing Tests
# Synthetic 15-page PDF with paragraphs, simple and complex tables, diagrams, scanned-form style image, metadata
# examples, and production RAG edge cases.
# Story Line
# Three client teams - Arka Finance, BlueLeaf Retail, and CityRide Mobility - are migrating contracts, policies, support records,
# and operational reports into a single RAG platform. Each team has different document types, access rules, and parsing
# challenges. The RAG system must answer questions with citations while ensuring that one client never sees another clients
# data.
# This PDF is intentionally designed to test document loaders, PDF parsers, OCR workflows, table extraction, chunking
# strategies, metadata preservation, and source citation quality.
# ...
